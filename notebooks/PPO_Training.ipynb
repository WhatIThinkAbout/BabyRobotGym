# %% [markdown]
# # Training the Baby Robot environment
#
# This uses the Stable Baseline PPO Reinforcement Learning algorithm to train Baby Robot to navigate a maze.
#
# To run training on Colab with a GPU takes about 20 minutes and without a GPU will take considerably longer, so it's worth checking that you have the GPU enabled
# (in Colab select the 'Runtime' toolbar option and then from "Change Runtime Type" set the Hardware accelerator to GPU). Additionally, after training the model will be saved, so its maybe worth copying this to Google Drive or somewhere similar to avoid retraining.

# %%
# set this true to train the model
# - otherwise it will try to load a pre-trained model
TRAIN_MODEL = True

# the name of the environment to create
Environment_Name = "BabyRobot-v0"

# define where the model should be written
model_dir = 'Models/'

# %%
# !pip install -q ipycanvas==0.11 -q
# !pip install --upgrade babyrobot -q
# !pip install stable-baselines3 -q

# %%
import os
import numpy as np
import gym
import babyrobot
from stable_baselines3.common.env_checker import check_env

# %%
# test if running in Google Colab
if 'COLAB_GPU' in os.environ:
  print("Setting Up For Google Colab")
  from google.colab import output
  output.enable_custom_widget_manager()

# %%
# create the specified environment with a discrete action space
setup = {'action_space':'discrete'}
env = gym.make(Environment_Name,**setup)

# use StableBaselines to check the environment
# - returns nothing if the environment is verified as ok
check_env(env)

# %%
setup = { 'width': 8,
          'height': 5,
          'add_maze': True,
          'maze_seed': 42,
          'end': [5,4],
          'add_compass':True 
        }       

puddles = [((2,2),2),           
           ((2,0),1),
           ((7,4),2),          
           ((5,1),2)]
setup['puddles'] = puddles

setup['grid'] = {'theme': 'black_orange'}
setup['side_panel'] = {'width':200}      

walls = [((2, 0),'E'), # remove the east wall at (2,0)
         ((1, 2),'S'),((2, 2),'S'),((2, 2),'E'),((3, 2),'S'),((4, 2),'S'),((3, 2),'E'),
         ((5, 2),'E')] # add an east wall at (5,2)   
setup['walls'] = walls

# %%
env = gym.make(Environment_Name,**setup)
env.render()
# Out:
# MultiCanvas(height=326, sync_image_data=True, width=718)

# %%
# add coodinates to see where we're working
info = {'coords': True}
env.show_info(info)

# %%
# remove the coordinates
env.clear_info(all_info=True)

# %% [markdown]
# ## Observation Space
#
# The environments default Observation Space is a MultiDiscrete space, which returns an [x,y] co-ordinate in the grid.

# %%
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape MultiDiscrete([8 5])
# Sample observation [0 4]

# %% [markdown]
# ## Action Space
#
# The default Action Space for the environment returns a Dynamic Space, where the action space for each cell contains only the valid actions for that cell. So, for example, the actions won't contain those that would make Baby Robot walk into a wall.

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 1
# Action Space Sample 2

# %% [markdown]
# # Stable Baselines Training
#
# Train the model on the environment using the _[PPO](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html)_ algorithm.

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
# Create environment
env = gym.make(Environment_Name,**setup)

# %% [markdown]
# ## Convert from MultiDiscrete to Discrete ObservationSpace
#
# Unfortunately the Stable Baselines PPO algorithm supports neither MultiDiscrete nor Dynamic spaces. We therefore need to convert both the Observation Space and the Action Space to make them into Discrete Spaces.
#
# For the Observation Space this means converting from grid co-ordinates into having a single ID to identify each cell in the grid. To do this we can use a **[wrapper](https://alexandervandekleut.github.io/gym-wrappers/)** around the Observation Space:

# %%
class DiscreteWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        assert isinstance(env.observation_space, gym.spaces.MultiDiscrete), \
            "Should only be used to wrap MultiDiscrete envs."        
        self.observation_space = gym.spaces.Discrete(env.observation_space[0].n * env.observation_space[1].n)
    
    def observation(self, obs):
        new_obs = (obs[0] + (obs[1] * self.env.observation_space[1].n))        
        return new_obs

# %% [markdown]
# For the Action Space we can simply specify that we want to use a Discrete space in the setup of the environment. This will result in all states in the grid having the 5 possible actions (Stay, North, South, East and West) as opposed to only valid actions that are state specific.

# %%
# create an environment with Discrete action and observation spaces
setup['action_space'] = 'discrete'
env = DiscreteWrapper(gym.make(Environment_Name,**setup))

# %%
env.reset()

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action

print("\n_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 5
# Action Space Sample 0
#
# _____OBSERVATION SPACE_____
#
# Observation Space Shape Discrete(40)
# Sample observation 8

# %%
# create the model
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# %%time

# test if the model should be trained
if TRAIN_MODEL:

  # Train the agent
  model.learn(total_timesteps=500_000)

  # Save the trained model
  model.save(f"{model_dir}/{Environment_Name}_ppo")
# Out:
# Streaming output truncated to the last 5000 lines.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.81e+03    |
# |    ep_rew_mean          | -1.89e+03   |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 8           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006199169 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.56        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 44.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.73e+03   |
# |    ep_rew_mean          | -1.8e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 9          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01123303 |
# |    clip_fraction        | 0.068      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.548      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.8        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 32.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.65e+03    |
# |    ep_rew_mean          | -1.72e+03   |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 10          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011630859 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.51        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 23.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.65e+03   |
# |    ep_rew_mean          | -1.72e+03  |
# | time/                   |            |
# |    fps                  | 457        |
# |    iterations           | 11         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01398039 |
# |    clip_fraction        | 0.0553     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.5       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0047    |
# |    value_loss           | 29.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.65e+03    |
# |    ep_rew_mean          | -1.72e+03   |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 12          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010841118 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.000554   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.000673    |
# |    value_loss           | 6.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.65e+03    |
# |    ep_rew_mean          | -1.72e+03   |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 13          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013686489 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.0155     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0703      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00688    |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.65e+03    |
# |    ep_rew_mean          | -1.72e+03   |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 14          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011380993 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.000726   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 2.15        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.24e+03   |
# |    ep_rew_mean          | -2.3e+03   |
# | time/                   |            |
# |    fps                  | 454        |
# |    iterations           | 15         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01287107 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.000385   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0196     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00192   |
# |    value_loss           | 1.25       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.24e+03     |
# |    ep_rew_mean          | -2.3e+03     |
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 16           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033758113 |
# |    clip_fraction        | 0.00396      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0362       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00571     |
# |    value_loss           | 22.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+03    |
# |    ep_rew_mean          | -2.3e+03    |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 17          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016901866 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.922      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0604      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 0.353       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | -2.46e+03    |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 18           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0072116964 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0757      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0174      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.43e+03     |
# |    ep_rew_mean          | -2.48e+03    |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 19           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0018808956 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 20           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.43e+03    |
# |    ep_rew_mean          | -2.48e+03   |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 20          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.000811129 |
# |    clip_fraction        | 0.004       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.42e+03    |
# |    ep_rew_mean          | -2.47e+03   |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 21          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009283451 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.0429      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.5e+03      |
# |    ep_rew_mean          | -2.55e+03    |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 22           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0042124223 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00632     |
# |    value_loss           | 4.49         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.96e+03     |
# |    ep_rew_mean          | -2e+03       |
# | time/                   |              |
# |    fps                  | 452          |
# |    iterations           | 23           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0052159727 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.65         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 8.49         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.63e+03      |
# |    ep_rew_mean          | -1.66e+03     |
# | time/                   |               |
# |    fps                  | 452           |
# |    iterations           | 24            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00013992199 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.837         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 52.4          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00137      |
# |    value_loss           | 72.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.34e+03      |
# |    ep_rew_mean          | -1.37e+03     |
# | time/                   |               |
# |    fps                  | 451           |
# |    iterations           | 25            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00038554156 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.901         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 23            |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00291      |
# |    value_loss           | 53.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.21e+03     |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 451          |
# |    iterations           | 26           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0010010181 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00376     |
# |    value_loss           | 69           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 27          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.001922149 |
# |    clip_fraction        | 0.00449     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 33.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | -977         |
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 28           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0026377975 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 33.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | -810         |
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 29           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0008054781 |
# |    clip_fraction        | 0.00112      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.6         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00426     |
# |    value_loss           | 76.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 633          |
# |    ep_rew_mean          | -650         |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 30           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0019462865 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.8         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00505     |
# |    value_loss           | 95.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | -285        |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 31          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.002847205 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 69.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 145        |
# |    ep_rew_mean          | -156       |
# | time/                   |            |
# |    fps                  | 446        |
# |    iterations           | 32         |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00557594 |
# |    clip_fraction        | 0.0374     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28         |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 56.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.5        |
# |    ep_rew_mean          | -98         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 33          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008234512 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 74.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.8        |
# |    ep_rew_mean          | -78.8       |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 34          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006989628 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 62.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.9        |
# |    ep_rew_mean          | -63.9       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 35          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009529328 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 42.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.3         |
# |    ep_rew_mean          | -57.1        |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 36           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0111665325 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0203      |
# |    value_loss           | 37.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.8        |
# |    ep_rew_mean          | -47.5       |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 37          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015055092 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 41.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.9        |
# |    ep_rew_mean          | -45.6       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 38          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011338627 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33          |
# |    ep_rew_mean          | -43.4       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 39          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008636676 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 32.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 40          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010723697 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 35.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.5         |
# |    ep_rew_mean          | -37.4        |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 41           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0066903853 |
# |    clip_fraction        | 0.097        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.777       |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 32           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.8        |
# |    ep_rew_mean          | -36.8       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 42          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007611393 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00862    |
# |    value_loss           | 23          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.1         |
# |    ep_rew_mean          | -37          |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 43           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0058370014 |
# |    clip_fraction        | 0.0823       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 23.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | -37.6       |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 44          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004229278 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 25.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | -36.2      |
# | time/                   |            |
# |    fps                  | 430        |
# |    iterations           | 45         |
# |    time_elapsed         | 213        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00354806 |
# |    clip_fraction        | 0.0527     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.523     |
# |    explained_variance   | 0.742      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.48       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00708   |
# |    value_loss           | 27.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | -35.1       |
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 46          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005207728 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00814    |
# |    value_loss           | 21          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23           |
# |    ep_rew_mean          | -33.1        |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 47           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0039439932 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24           |
# |    ep_rew_mean          | -34.5        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 48           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0021955897 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.31         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 16.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -32.7       |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 49          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002555008 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.75        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 19          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.9         |
# |    ep_rew_mean          | -33.2        |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 50           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0026936117 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.337       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 15.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.3         |
# |    ep_rew_mean          | -36.2        |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 51           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0016161895 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.32        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.38         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 17.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23           |
# |    ep_rew_mean          | -33          |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 52           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0030542347 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.315       |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.4         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 24.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.4         |
# |    ep_rew_mean          | -40.5        |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 53           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0063722413 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.327       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.1         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00698     |
# |    value_loss           | 18.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.7       |
# |    ep_rew_mean          | -32.5      |
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 54         |
# |    time_elapsed         | 261        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.05409647 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.35      |
# |    explained_variance   | 0.0391     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.29       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0301    |
# |    value_loss           | 25.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | -32.7       |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 55          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.009813621 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 25.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.2         |
# |    ep_rew_mean          | -33.1        |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 56           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0028512848 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 20.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | -35.3       |
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 57          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.002856341 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.82        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00552    |
# |    value_loss           | 18.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.4         |
# |    ep_rew_mean          | -33.9        |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 58           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0030997545 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00636     |
# |    value_loss           | 28.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.4         |
# |    ep_rew_mean          | -32.4        |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 59           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0030172986 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.36         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00476     |
# |    value_loss           | 23.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.5        |
# |    ep_rew_mean          | -32.9       |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 60          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.004959782 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 20.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.4         |
# |    ep_rew_mean          | -32.7        |
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 61           |
# |    time_elapsed         | 299          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0027559632 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.6         |
# |    n_updates            | 600          |
# ...
# |    total_timesteps      | 466944        |
# | train/                  |               |
# |    approx_kl            | 0.00033849318 |
# |    clip_fraction        | 0.00557       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.114        |
# |    explained_variance   | 0.773         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.49          |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -0.000155     |
# |    value_loss           | 19.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.7         |
# |    ep_rew_mean          | -31.4        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 229          |
# |    time_elapsed         | 1229         |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0017037125 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0979      |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.49         |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 22.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22           |
# |    ep_rew_mean          | -32.5        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 230          |
# |    time_elapsed         | 1234         |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 0.0010315136 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.118       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.000506    |
# |    value_loss           | 21.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.5          |
# |    ep_rew_mean          | -31.7         |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 231           |
# |    time_elapsed         | 1240          |
# |    total_timesteps      | 473088        |
# | train/                  |               |
# |    approx_kl            | 0.00088215026 |
# |    clip_fraction        | 0.00728       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.109        |
# |    explained_variance   | 0.77          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 10.2          |
# |    n_updates            | 2300          |
# |    policy_gradient_loss | -0.000738     |
# |    value_loss           | 20.6          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.3        |
# |    ep_rew_mean          | -32.6       |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 232         |
# |    time_elapsed         | 1245        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.001510839 |
# |    clip_fraction        | 0.00723     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0967     |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.000852   |
# |    value_loss           | 18.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | -32.1        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 233          |
# |    time_elapsed         | 1251         |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0010396738 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.000925    |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.9          |
# |    ep_rew_mean          | -32.3         |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 234           |
# |    time_elapsed         | 1256          |
# |    total_timesteps      | 479232        |
# | train/                  |               |
# |    approx_kl            | 0.00057374267 |
# |    clip_fraction        | 0.00498       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.112        |
# |    explained_variance   | 0.741         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.6          |
# |    n_updates            | 2330          |
# |    policy_gradient_loss | -0.000496     |
# |    value_loss           | 22.6          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.9          |
# |    ep_rew_mean          | -31.4         |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 235           |
# |    time_elapsed         | 1262          |
# |    total_timesteps      | 481280        |
# | train/                  |               |
# |    approx_kl            | 0.00095471856 |
# |    clip_fraction        | 0.0138        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0978       |
# |    explained_variance   | 0.729         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.29          |
# |    n_updates            | 2340          |
# |    policy_gradient_loss | -0.00127      |
# |    value_loss           | 25.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.7         |
# |    ep_rew_mean          | -31.5        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 236          |
# |    time_elapsed         | 1267         |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0094833765 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.6          |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 15.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -33.9       |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 237         |
# |    time_elapsed         | 1273        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.003895843 |
# |    clip_fraction        | 0.0185      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.33        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 18.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 238         |
# |    time_elapsed         | 1278        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.002162708 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.135      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.000538   |
# |    value_loss           | 24.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.2         |
# |    ep_rew_mean          | -32.4        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 239          |
# |    time_elapsed         | 1284         |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0012591671 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 0.79         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.000615    |
# |    value_loss           | 19.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | -32.2        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 240          |
# |    time_elapsed         | 1289         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0019819336 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.79         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.3          |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 19.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | -32.3        |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 241          |
# |    time_elapsed         | 1295         |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0017931066 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 19.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -32.1        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 242          |
# |    time_elapsed         | 1300         |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0016849334 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.114       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.6          |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.000875    |
# |    value_loss           | 17.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.3         |
# |    ep_rew_mean          | -32.5        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 243          |
# |    time_elapsed         | 1306         |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0014502837 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.54         |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.000704    |
# |    value_loss           | 18.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.7         |
# |    ep_rew_mean          | -31.7        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 244          |
# |    time_elapsed         | 1312         |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0019203473 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.135       |
# |    explained_variance   | 0.817        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.43         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 16.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.2         |
# |    ep_rew_mean          | -32.5        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 245          |
# |    time_elapsed         | 1317         |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0013113201 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.104       |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 16.1         |
# ------------------------------------------
# CPU times: user 21min 41s, sys: 23.9 s, total: 22min 5s
# Wall time: 21min 59s

# %% [markdown]
# ## Load and Evaluate the Trained Model

# %%
# load the pre-trained model
model = PPO.load(f"{model_dir}/{Environment_Name}_ppo", print_system_info=True)
# Out:
# == CURRENT SYSTEM INFO ==
# OS: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic #1 SMP Sun Apr 24 10:03:06 PDT 2022
# Python: 3.7.13
# Stable-Baselines3: 1.6.0
# PyTorch: 1.12.0+cu113
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0
#
# == SAVED MODEL SYSTEM INFO ==
# OS: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic #1 SMP Sun Apr 24 10:03:06 PDT 2022
# Python: 3.7.13
# Stable-Baselines3: 1.6.0
# PyTorch: 1.12.0+cu113
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0

# %%
eval_env = DiscreteWrapper(gym.make(Environment_Name,**setup))
eval_env.render()
# Out:
# MultiCanvas(height=326, sync_image_data=True, width=718)

# %%
obs = eval_env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, done, info = eval_env.step(action)
    eval_env.render()
    if done:
      break
